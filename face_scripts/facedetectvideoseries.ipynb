# %%
import os
import numpy as np
import cv2
import random
from matplotlib import pyplot as plt

# %% [markdown]
# layer allows us to define a custom layer for neural network
# cov lets us conv
# dense makes dense neural network
# maxpooling makes it small

# %%
#importing tensorflow dependencies

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer,Conv2D,Dense,MaxPooling2D,Input,Flatten
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
len(gpus)
# Out:
# 0

# %%
# Setup paths
POS_PATH = os.path.join('data', 'positive')
print(POS_PATH)
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')
print(NEG_PATH)
print(ANC_PATH)
#LFW_PATH = os.path.join('data', 'lfw')
# Out:
# data/positive
# data/negative
# data/anchor

# %%
print(os.getcwd())
# Out:
# /home/user/VScode_PS1/script

# %%
os.listdir('lfw')
# Out:
# ['Sonja_Kesselschlager',
#  'Paula_Prentiss',
#  'Ester_Canadas',
#  'Patricia_Hearst',
#  'Doug_Racine',
#  'Holly_Robinson_Peete',
#  'Don_Boudria',
#  'Raja_Zafar-ul-Haq',
#  'Mary_Lou_Retton',
#  'Carroll_Weimer',
#  'Laurent_Woulzy',
#  'Walter_Woods',
#  'Akbar_Hashemi_Rafsanjani',
#  'Leslie_Wiser_Jr',
#  'Michael_Chang',
#  'Charles_Kartman',
#  'Roger_Winter',
#  'Alejandro_Toledo',
#  'Alejandro_Fernandez',
#  'Gerry_Adams',
#  'Liam_Neeson',
#  'Muhammad_Saeed_al-Sahhaf',
#  'Sue_Slavec',
#  'William_Hochul',
#  'Marc_Gold',
#  'Frank_Keating',
#  'Leah_Remini',
#  'Carlo_Ancelotti',
#  'Felicity_Huffman',
#  'John_Elway',
#  'Raul_Rivero',
#  'Howard_Smith',
#  'Elsa_Zylberstein',
#  'Judy_Dean',
#  'Thomas_Daily',
#  'Mike_Eskew',
#  'Rob_Schneider',
#  'Dennis_Kozlowski',
#  'Julio_Cesar_Chavez',
#  'Michael_Hoffa',
#  'Francis_Mer',
#  'Eric_Lindros',
#  'Ramon_Ponce_de_Leon',
#  'Oscar_DLeon',
#  'Dariusz_Michalczewski',
#  'James_Brown',
#  'Jane_Walker_Wood',
#  'Damon_van_Dam',
#  'Bela_Karolyi',
#  'Saeb_Erekat',
#  'Linda_Amicangioli',
#  'Dale_Bosworth',
#  'Kent_McCord',
#  'Marie-Reine_Le_Gougne',
#  'Derek_Parra',
#  'Cindy_Klassen',
#  'Brenda_Magana',
#  'Annette_Bening',
#  'Michael_Jordan',
#  'Francois_Botha',
#  'Bob_Riley',
#  'Mary_Carey',
#  'Clive_Lloyd',
#  'Todd_Haynes',
#  'David_Carradine',
#  'Robbie_Fowler',
#  'Penelope_Taylor',
#  'Robert_Altman',
#  'Brawley_King',
#  'Bob_Stoops',
#  'John_McCormack',
#  'Jack_Smith',
#  'Spike_Jonze',
#  'Joe_Pantoliano',
#  'Andre_Bucher',
#  'Slobodan_Milosevic',
#  'Leuris_Pupo',
#  'David_Beckham',
#  'Lydia_Shum',
#  'Brian_Heidik',
#  'Ethan_Hawke',
#  'Federico_Trillo',
#  'Bill_Richardson',
#  'Theo_Angelopoulos',
#  'Helio_Rubens_Garcia',
#  'Lisa_Gottsegen',
#  'Darren_Campel',
#  'Elizabeth_Smart',
#  'Paula_Radcliffe',
#  'Ramon_Cardenas',
#  'Collis_Temple_III',
#  'Fred_Eckhard',
#  'Kirk_Franklin',
#  'Marlon_Devonish',
#  'Peter_Albertsen',
#  'Marcus_Allen',
#  'Joe_Leonard',
#  'Jimmy_Gurule',
#  'Robert_Woody_Johnson',
#  'Warren_Buffett',
#  'Khaled_Sawalhi',
#  'Paola_Espinoza',
#  'Jorge_Arce',
#  'Patrick_Clawsen',
#  'Lisa_Ling',
#  'Jeff_Schiffner',
#  'Tyrone_Medley',
#  'Aby_Har-Even',
#  'Ulrich_Kueperkoch',
#  'John_Norquist',
#  'Imad_Khadduri',
#  'Sofia_Milos',
#  'Olivia_Newton-John',
#  'Zelma_Novelo',
#  'Lope_Mendoza',
#  'Ben_Howland',
#  'Sharon_Osbourne',
#  'Paula_Dobriansky',
#  'Kim_Clijsters',
#  'Mike_Helton',
#  'Bruna_Colosio',
#  'Raymond_Odierno',
#  'Ian_Huntley',
#  'Cedric_Benson',
#  'Paul_Farley',
#  'Garry_Kasparov',
#  'Shane_Warne',
#  'Katerina_Smrzova',
#  'John_Engler',
#  'Romain_Duris',
#  'Mohammad_Fares',
#  'Eric_Staal',
#  'Retief_Goosen',
#  'Costas_Simitis',
#  'Frank_Van_Ecke',
#  'Zach_Safrin',
#  'Priscilla_Owen',
#  'Marina_Hands',
#  'Lori_Berenson',
#  'Dan_Wheldon',
#  'Justin_Timberlake',
#  'Brandon_Knight',
#  'Kirsten_Dunst',
#  'Daniel_Radcliffe',
#  'Bill_Graham',
#  'Brad_Banks',
#  'Brenda_Wilson',
#  'Gustavo_Cisneros',
#  'Kim_Yun-kyu',
#  'Mary_Matalin',
#  'Hilary_McKay',
#  'Eddie_Murray',
#  'Heath_Ledger',
#  'Michael_Bouchard',
#  'Angelo_Genova',
#  'Adam_Scott',
#  'Brian_Schneider',
#  'Stan_Kroenke',
#  'Calista_Flockhart',
#  'Patsy_Hardy',
#  'Shoshannah_Stern',
#  'Mark_Hurlbert',
#  'Kenneth_Dam',
#  'Eileen_Spina',
#  'Joseph_Ganim',
#  'Steve_Lenard',
#  'Steven_Kinlock',
#  'Vincent_Brooks',
#  'Christian_Malcolm',
#  'Yasushi_Akashi',
#  'Jerelle_Kraus',
#  'Nancy_Demme',
#  'John_Sidgmore',
#  'Craig_Morgan',
#  'Abbas_Kiarostami',
#  'Robert_Schuller',
#  'Raja_Ramani',
#  'Michele_Placido',
#  'Carson_Palmer',
#  'Chris_Kolanas',
#  'Herb_Dhaliwal',
#  'Amanda_Bynes',
#  'Gonzalo_Sanchez_de_Lozada',
#  'Hassanal_Bolkiah',
#  'Anderson_Varejao',
#  'Chin-Hui_Tsao',
#  'Jason_Kidd',
#  'Alicia_Hollowell',
#  'Denys_Arcand',
#  'Theresa_Gattung',
#  'Svetoslav_Todorov',
#  'Jane_Kaczmarek',
#  'Barrett_Jackman',
#  'Geno_Auriemma',
#  'Lyle_Lovett',
#  'Theresa_May',
#  'Ernie_Harwell',
#  'Sandra_Shamas',
#  'Lima_Azimi',
#  'Trista_Rehn',
#  'David_Dewayne_Williams',
#  'Dean_Jacek',
#  'Nursultan_Nazarbayev',
#  'James_Williams',
#  'Carlos_Lordkipanitse',
#  'Humberto_Coelho',
#  'Ariel_Sharon',
#  'Sasha_Cohen',
#  'Ana_Claudia_Talancon',
#  'Lee_Hoi-chang',
#  'Rey_Sanchez',
#  'Sean_Astin',
#  'Jason_White',
#  'Dale_Earnhardt',
#  'Gustavo_Kuerten',
#  'Oscar_Bolanos',
#  'Martin_Short',
#  'AJ_Cook',
#  'Patrick_Bourrat',
#  'John_Sununu',
#  'Bill_Stapleton',
#  'Nicolas_Eyzaguirre',
#  'Dennis_Hastert',
#  'Mike_Sherman',
#  'Abid_Hamid_Mahmud_Al-Tikriti',
#  'Aaron_Sorkin',
#  'Stephanie_Zimbalist',
#  'Conchita_Martinez',
#  'Wayne_Gretzky',
#  'Juan_Carlos',
#  'Aaron_Eckhart',
#  'Kevin_Borseth',
#  'Moby',
#  'Andy_Warhol',
#  'Vanessa_Williams',
#  'Joey_Buttafuoco',
#  'Khatol_Mohammad_Zai',
#  'Greg_Owen',
#  'Jason_Statham',
#  'Horst_Koehler',
#  'John_Hartson',
#  'Ivan_Helguera',
#  'Kate_Moss',
#  'Romario_Farias',
#  'Dean_Barker',
#  'Eddie_Fenech_Adami',
#  'Izzat_Ibrahim',
#  'Sean_Townsend',
#  'Gregory_Geoffroy',
#  'Constance_Marie',
#  'Yekaterina_Guseva',
#  'Tristan_Gretzky',
#  'Biljana_Plavsic',
#  'Andre_Agassi',
#  'Geoffrey_Rush',
#  'Dan_Monson',
#  'Patrik_Kristiansson',
#  'Larry_Bowa',
#  'Hushiar_Zebari',
#  'Kultida_Woods',
#  'Sam_Brownback',
#  'Yoon_Jeong_Cho',
#  'Lee_Ann_Womack',
#  'Lee_Jun',
#  'Jaime_Pressly',
#  'Dick_Cheney',
#  'Adam_Herbert',
#  'Lois_Smart',
#  'Kiki_Vandeweghe',
#  'Richard_Naughton',
#  'John_Goold',
#  'Bill_Frist',
#  'Stephen_Ambrose',
#  'David_Brinkley',
#  'Jiri_Novak',
#  'Russell_Simmons',
#  'Didier_Defago',
#  'Kirk_Douglas',
#  'LeAnn_Rimes',
#  'William_Macy',
#  'Scott_Peterson',
#  'Steny_Hoyer',
#  'David_Nalbandian',
#  'Mary_Anne_Souza',
#  'Kathryn_Grayson',
#  'Joseph_Galante',
#  'Yoko_Ono',
#  'Jim_Flaherty',
#  'William_Webster',
#  'Princess_Aiko',
#  'David_McKiernan',
#  'Patsy_Mink',
#  'Steven_Craig',
#  'Michael_Hagee',
#  'Trent_Lott',
#  'Aline_Chretien',
#  'Ewan_McGregor',
#  'Hiroyuki_Yoshino',
#  'Bob_Hayes',
#  'Hernan_Diaz',
#  'George_Bovell',
#  'Katie_Smith',
#  'Robbie_Mc_Ewen',
#  'Charles_Tannok',
#  'Peter_Bacanovic',
#  'Ivana_Trump',
#  'Angela_Lansbury',
#  'Brian_Lara',
#  'Darrell_Issa',
#  'Vince_Dooley',
#  'Gwendal_Peizerat',
#  'Kaye_Young',
#  'Mohammed_Abulhasan',
#  'Abdel_Aziz_Al-Hakim',
#  'John_Jones',
#  'Sophia_Loren',
#  'Gary_Paer',
#  'Takaloo',
#  'Casey_Crowder',
#  'Daniel_Darnell',
#  'Will_Ferrell',
#  'Scott_Blum',
#  'Cate_Blanchett',
#  'Jim_Fassel',
#  'Prince_William',
#  'Keith_Urban',
#  'Tim_Howard',
#  'Edward_Egan',
#  'Serge_Klarsfeld',
#  'Daryl_Parks',
#  'Brooke_Adams',
#  'Conan_OBrien',
#  'Paul_Ebert',
#  'Stefano_Accorsi',
#  'Leigh_Winchell',
#  'Hitoshi_Oshitani',
#  'Fred_Durst',
#  'Itzhak_Perlman',
#  'Jorge_Enrique_Jimenez',
#  'Brad_Russ',
#  'Valery_Giscard_dEstaing',
#  'Anne_Krueger',
#  'Martin_Torrijos',
#  'Nicanor_Duarte_Frutos',
#  'Robert_Wiener',
#  'Hamid_Efendi',
#  'Roger_Corbett',
#  'Daniel_Comisso_Urdaneta',
#  'Muammar_Gaddafi',
#  'Rubens_Barrichello',
#  'Jeffrey_Ashby',
#  'Ed_Wade',
#  'Chuck_Hagel',
#  'Alecos_Markides',
#  'Cristina_Torrens_Valero',
#  'Dalia_Rabin-Pelosoff',
#  'Morris_Dees',
#  'Claire_Tomalin',
#  'Don_Flanagan',
#  'Dan_Duquette',
#  'Michael_Friedman',
#  'Alessandra_Cerna',
#  'Mario_Dominguez',
#  'Edmund_Stoiber',
#  'Jane_Rooney',
#  'Michelle_Kwan',
#  'Andy_Bryant',
#  'Ken_Watanabe',
#  'Mara_Georges',
#  'Melissa_Mulloy',
#  'James_Becker',
#  'Francis_Ricciardone',
#  'Abel_Aguilar',
#  'Sung_Hong_Choi',
#  'Neil_Moritz',
#  'Tiger_Woods',
#  'Cindy_Crawford',
#  'Barbara_De_Brun',
#  'Peter_Gabriel',
#  'Len_Jenoff',
#  'Timothy_Coughlin',
#  'Harold_Scott',
#  'Jason_Sorens',
#  'Peter_Sejna',
#  'Al_Sharpton',
#  'Lisa_Stansfield',
#  'Celine_Dion',
#  'Eugene_Teslovic',
#  'Qais_al-Kazali',
#  'Pete_Rose',
#  'Mary_Blige',
#  'Christine_Ebersole',
#  'Grace_Brinell',
#  'Robert_Wagner',
#  'Vassilis_Xiros',
#  'Curtis_Rodriguez',
#  'Anne_McLellan',
#  'Mitch_Kupchak',
#  'Stuart_Whitman',
#  'John_Banko',
#  'Esteban_Cordoba-Velazquez',
#  'Barry_Nakell',
#  'Jimmy_Iovine',
#  'Brandon_Inge',
#  'Manuel_Llorente',
#  'Barbara_Boxer',
#  'Brian_Jordan',
#  'Paul_William_Hurley',
#  'Rachel_Wheatley',
#  'Ian_Gillan',
#  'Dino_Risi',
#  'Mike_Samp',
#  'Betty_Garrison',
#  'Rien_Long',
#  'Magdalena_Maleeva',
#  'Hu_Jintao',
#  'Lene_Espersen',
#  'Zeng_Qinghong',
#  'Michael_Sullivan',
#  'Don_Henley',
#  'Norbert_van_Heyst',
#  'Stephen_Funk',
#  'Patrick_Coleman',
#  'Joao_Rocha',
#  'Joan_Laporta',
#  'Lee_Nam-shin',
#  'Bill_Hughes',
#  'Yasushi_Chimura',
#  'Michael_Haneke',
#  'Tara_Dawn_Christensen',
#  'Nathalie_Baye',
#  'Alfredo_Moreno',
#  'Ben_Kingsley',
#  'Eliza_Dushku',
#  'Rodney_Rempt',
#  'Jaap_de_Hoop_Scheffer',
#  'Queen_Elizabeth_II',
#  'Rachel_Roy',
#  'Ralph_Friedgen',
#  'Matt_Siebrandt',
#  'Jafar_Umar_Thalib',
#  'Phil_Bennett',
#  'Eric_Idle',
#  'Danny_Glover',
#  'Nicolas_Lapentti',
#  'Enrique_Medina_Gomez',
#  'Allison_Janney',
#  'Tono_Suratman',
#  'Astrid_Betancourt',
#  'Sohail_Abbas',
#  'William_Ragland',
#  'Sok_An',
#  'Julie_Andrews',
#  'Sergei_Yushenkov',
#  'Charles_Mathews',
#  'Eduardo_Duhalde',
#  'Larry_Campbell',
#  'Billy_Beane',
#  'Vernon_Forrest',
#  'Adam_Ant',
#  'Jenna_Elfman',
#  'Anton_Balasingham',
#  'Tyler_Grillo',
#  'Eddie_Jordan',
#  'Paulie_Ayala',
#  'Guillermo_Coria',
#  'Edward_Albee',
#  'Jorge_Rodolfo_Canicoba_Corral',
#  'Joseph_Salgado',
#  'Carlton_Dotson',
#  'Andrea_Kiser',
#  'Patti_Labelle',
#  'Brad_Gushue',
#  'Franz_Beckenbauer',
#  'Steve_Case',
#  'Paul_Kelleher',
#  'Paul_Johnson',
#  'Earl_Counter',
#  'Hikmat_al-Azzawi',
#  'Adrian_Annus',
#  'Tommy_Haas',
#  'Christiane_Wulff',
#  'Malak_Habbak',
#  'Billy_Gilman',
#  'Mike_Alden',
#  'Alexandre_Vinokourov',
#  'Timbul_Silaen',
#  'Stephen_Frears',
#  'Adam_Sandler',
#  'Mohammad_Mustapha_Miro',
#  'David_Montoya',
#  'Nan_Wang',
#  'Richard_Crenna',
#  'William_Rehnquist',
#  'Alonzo_Mourning',
#  'Jeri_Ryan',
#  'Doc_Rivers',
#  'Sophie',
#  'Sammy_Sosa',
#  'Brendan_Stai',
#  'Cecilia_Cheung',
#  'Sam_Torrance',
#  'Darvis_Patton',
#  'Masaru_Hayami',
#  'Wolfgang_Clement',
#  'Michael_Powell',
#  'Mark_Leno',
#  'Chelsea_Clinton',
#  'Rhett_Warrener',
#  'Julianna_Margulies',
#  'Derek_King',
#  'Michael_Shelby',
#  'Arnold_Scott',
#  'Filip_De_Winter',
#  'Harry_Schmidt',
#  'Hideki_Sato',
#  'Michael_Rolinee',
#  'Peter_Holmberg',
#  'Anthony_Lee_Johnson',
#  'Tom_Smothers',
#  'Peter_Hillary',
#  'Zdravko_Mucic',
#  'Keizo_Yamada',
#  'Barbara_Bach',
#  'Bob_Dole',
#  'Severino_Antinori',
#  'Sedigh_Barmak',
#  'Buford_Blount',
#  'Dan_Prinster',
#  'Goran_Persson',
#  'Masao_Azuma',
#  'Paul_Tracy',
#  'Lemuel_Montulo',
#  'Michael_Donovan',
#  'Jennifer_Love_Hewitt',
#  'Mark_Geragos',
#  'Jesse_Helms',
#  'Ricky_Barnes',
#  'Brett_Hawke',
#  'Hunter_Kemper',
#  'Hamad_Bin_Isa_al-Khalifa',
#  'Glen_Sather',
#  'Tom_OBrien',
#  'Guillaume_Cannet',
#  'Frank_Hsieh',
#  'Dean_Barkley',
#  'Timothy_Wirth',
#  'Fernando_Hierro',
#  'Mario_Jardel',
#  'Kitin_Munoz',
#  'Daniel_Zelman',
#  'Mike_Miller',
#  'Sarah_Wynter',
#  'David_Brent',
#  'Rafael_Vinoly',
#  'Mark_Komara',
#  'Cass_Ballenger',
#  'Elijan_Ingram',
#  'Kristin_Davis',
#  'Rod_Blagojevich',
#  'Rene_Antonio_Leon_Rodriguez',
#  'Anne_Cavers',
#  'Shawn_Bradley',
#  'Kevin_James',
#  'Chris_Whitney',
#  'James_Spalding',
#  'Emanuel_Ginobili',
#  'Claudia_Coslovich',
#  'Kenneth_Branagh',
#  'Bob_Krueger',
#  'Ian_Smith',
#  'Cecilia_Chang',
#  'Robert_Hanssen',
#  'Kim_Dae-jung',
#  'Mark_Salter',
#  'Yann_Martel',
#  'Carson_Daly',
#  'Brock_Berlin',
#  'MC_Hammer',
#  'Wayne_Brady',
#  'Abdullah_Ahmad_Badawi',
#  'Scott_Wallach',
#  'Paul_Burrell',
#  'Don_Lake',
#  'Rich_Brooks',
#  'Steve_Nash',
#  'Denise_Johnson',
#  'Bernard_Siegel',
#  'Rena_Sofer',
#  'Kenneth_Bowersox',
#  'Steve_Kerr',
#  'Roberto_Marinho',
#  'Carla_Gay_Balingit',
#  'Nila_Ferran',
#  'Terry_Hoeppner',
#  'Anthony_Hopkins',
#  'Don_King',
#  'Steve_McManaman',
#  'Jerry_Colangelo',
#  'Matt_Welsh',
#  'Riek_Blanjaar',
#  'Garth_Drabinsky',
#  'Park_Na-kyong',
#  'Sean_Patrick_OMalley',
#  'Dan_Morales',
#  'Fruit_Chan',
#  'Chan_Choi',
#  'Jason_Clermont',
#  'Jayson_Williams',
#  'Werner_Schlager',
#  'Simon_Chalk',
#  'Toni_Braxton',
#  'Ahmad_Jbarah',
#  'Derian_Hatcher',
#  'Brad_Garrett',
#  'Terunobu_Maeda',
#  'Xiang_Huaicheng',
#  'Denise_Locke',
#  'Camille_Lewis',
#  'Anna_Kournikova',
#  'David_Oh',
#  'Malcolm_Jamal_Warner',
#  'Shannon_OBrien',
#  'Teresa_Worbis',
#  'Pedro_Alvarez',
#  'Natalie_Maines',
#  'Peter_Rasch',
#  'Jorma_Huhtala',
#  'James_Mathis',
#  'James_Kopp',
#  'John_McKay',
#  'Chris_Rock',
#  'Takahiro_Mori',
#  'Ajit_Agarkar',
#  'Esther_Macklin',
#  'Michael_Pfleger',
#  'Jaromir_Jagr',
#  'Mike_Tyson',
#  'Mstislav_Rostropovich',
#  'Jan_Paul_Miller',
#  'Daniel_Montgomery',
#  'Monte_Kiffin',
#  'Jonathan_Woodgate',
#  'Jan_Pronk',
#  'Alejandro_Gonzalez_Inarritu',
#  'Kamel_Morjane',
#  'Ken_Macha',
#  'Columba_Bush',
#  'Jane_Pauley',
#  'Gerrit_Zalm',
#  'James_Traficant',
#  'Lucio_Angulo',
#  'Clemente_de_la_Vega',
#  'Antje_Buschschulte',
#  'Gustavo_Noboa',
#  'Barry_Williams',
#  'Rick_Rickert',
#  'Stan_Kasten',
#  'Steve_Patterson',
#  'Nizar_Trabelsi',
#  'Jane_Menelaus',
#  'Warren_Beatty',
#  'Phil_McGraw',
#  'Jerry_Rice',
#  'Gerald_Calabrese',
#  'Wanda_Ilene_Barzee',
#  'Vicente_Fox_de_la_Concha',
#  'Joe_Dicaro',
#  'Helio_Castroneves',
#  'Kevin_Crane',
#  'Anne_Donovan',
#  'Peri_Gilpin',
#  'Jason_Biggs',
#  'Leandrinho_Barbosa',
#  'John_Stockton',
#  'Rick_Husband',
#  'Jim_Greenwood',
#  'Tim_Duncan',
#  'Efrain_Rios_Montt',
#  'Markus_Beyer',
#  'Viara_Vike-Freiberga',
#  'Kim_Jin-sun',
#  'Bixente_LIzarazu',
#  'Mathias_Reichhold',
#  'Calbert_Cheaney',
#  'Perri_Shaw',
#  'Tatyana_Tomashova',
#  'Marco_Irizarry',
#  'Jim_Leach',
#  'Jamie_Lee_Curtis',
#  'Bob_Colvin',
#  'Nicole_Hiltz',
#  'Antonio_Catania',
#  'Tayshaun_Prince',
#  'Horacio_de_Jesus_Montoya',
#  'Marcelo_Bielsa',
#  'Penny_Dupuie',
#  'John_McCain',
#  'Craig_Doblin',
#  'Nina_Pecari',
#  'Gavin_Degraw',
#  'Kai-Uwe_Ricke',
#  'Samantha_Ledster',
#  'Dora_Bakoyianni',
#  'Mauricio_Macri',
#  'Ray_Wasden',
#  'Hoda_Asfor',
#  'Zahir_Shah',
#  'John_Madden',
#  'Colin_Campbell',
#  'Georgina_Bardach',
#  'Richard_Fine',
#  'Greg_Hennigar',
#  'Kurt_Budke',
#  'Gary_Leon_Ridgway',
#  'John_Eastman',
#  'Daryl_Sabara',
#  'Paul_ONeill',
#  'Melissa_Stark',
#  'Lou_Reed',
#  'Richard_Pennington',
#  'Michael_Killeen',
#  'Mike_Babcock',
#  'Heidi_Klum',
#  'Enrique_Haroldo_Gorriaran_Merlo',
#  'Peter_Gilmour',
#  'David_Shayler',
#  'Frank_Zappa',
#  'Nancy_Pelosi',
#  'Antanas_Valionis',
#  'Terrence_Kiel',
#  'Nick_Markakis',
#  'David_Heyman',
#  'Dick_Clark',
#  'Mona_Locke',
#  'Marsha_Thomason',
#  'Jack_Welch',
#  'Ted_Washington',
#  'Arlen_Specter',
#  'Joseph_Kabila',
#  'Susan_Collins',
#  'Rolandas_Paksas',
#  'Jennifer_Granholm',
#  'Erin_Brockovich',
#  'Marcus_Gronholm',
#  'Nona_Gaye',
#  'James_Lockhart',
#  'Mike_Bryan',
#  'Erskine_Bowles',
#  'Aaron_Peirsol',
#  'Emma_Thompson',
#  'Eve_Ensler',
#  'Geoff_Dixon',
#  'Tony_Curtis',
#  'Cori_Enghusen',
#  'Valeri_Bure',
#  'Graeme_Lloyd',
#  'Theodore_Tweed_Roosevelt',
#  'Gerard_Kleisterlee',
#  'Princess_Victoria',
#  'Akiko_Morigami',
#  'Din_Samsudin',
#  'Mark_Broxmeyer',
#  'Alain_Ducasse',
#  'Frank_Cassell',
#  'Eloy_Gutierrez',
#  'Ashley_Judd',
#  'Leni_Bjorklund',
#  'Beyonce_Knowles',
#  'Michael_Milton',
#  'Roger_Moore',
#  'Boris_Jordan',
#  'Richard_Parsons',
#  'Mary_Bono',
#  'Jeffery_Strelzin',
#  'Etta_James',
#  'Cabas',
#  'William_Swor',
#  'Igor_Ivanov',
#  'Jennifer_Thompson',
#  'Carmen_Electra',
#  'Barbara_Becker',
#  'David_Coulthard',
#  'Jose_Genoino',
#  'Hasan_Wirayuda',
#  'Tony_Parker',
#  'Jong_Wook_Lee',
#  'Khalid_Khannouchi',
#  'Bruno_Junquiera',
#  'Jim_Wong',
#  'Kenneth_Reichert',
#  'Rogelio_Montemayor',
#  'Elizabeth_Dole',
#  'Ed_Smart',
#  'Dan_LaCoutre',
#  'Larry_Nichols',
#  'Matt_Morris',
#  'Paula_Abdul',
#  'Laura_Schlessinger',
#  'Johnny_Unitas',
#  'Amr_Moussa',
#  'Rodrigo_de_la_Cerna',
#  'Shaun_Rusling',
#  'Paul_Wollnough',
#  'Frederique_van_der_Wal',
#  'Debra_Brown',
#  'Hans_Corell',
#  'Colin_Cowie',
#  'Nate_Huffman',
#  'Goran_Zivkovic',
#  'Bill_Byrne',
#  'Tanya_Lindenmuth',
#  'Daja_Bedanova',
#  'Shane_Hmiel',
#  'Mary_Descenza',
#  'Leandro_Garcia',
#  'Stephen_Cooper',
#  'Nate_Blackwell',
#  'Pat_Burns',
#  'Svetlana_Belousova',
#  'Omar_Vizquel',
#  'Rafeeuddin_Ahmed',
#  'Filippo_Volandri',
#  'Makiya_Ali_Hassan',
#  'Timothy_Rigas',
#  'Steve_Phillips',
#  'Gracia_Burnham',
#  'Jose_Viegas_Filho',
#  'Agnelo_Queiroz',
#  'Pedro_Velasquez',
#  'Vanessa_Redgrave',
#  'Richard_Barry',
#  'Faye_Alibocus',
#  'Kyoko_Nakayama',
#  'Tom_Rouen',
#  'Keanu_Reeves',
#  'Sebastian_Saja',
#  'Nora_Bendijo',
#  'Sylvester_Stallone',
#  'Richard_Sterner',
#  'Colleen_Ryan',
#  'Raquel_Welch',
#  'Jim_Parque',
#  'Lili_Taylor',
#  'Mark_Martin',
#  'Jimmy_Szymanski',
#  'Koichi_Tanaka',
#  'Paul_Bettany',
#  'Lawrence_Roberts',
#  'John_Fenn',
#  'Lubomir_Zaoralek',
#  'Gus_Van_Sant',
#  'Nur_Jaafar',
#  'Nick_Price',
#  'Jeremy_Gompertz',
#  'Milo_Maestrecampo',
#  'Margaret_Okayo',
#  'Winona_Ryder',
#  'Curtis_Strange',
#  'Catherine_Zeta-Jones',
#  'Danny_Morgan',
#  'Fujio_Mitarai',
#  'Uma_Thurman',
#  'John_Salazar',
#  'Abdullah_Gul',
#  'Antonio_Bernardo',
#  'Gary_Gitnick',
#  'Alice_Fisher',
#  'Eli_Broad',
#  'Junichi_Inamoto',
#  'Eduardo_Romero',
#  'Ari_Fleischer',
#  'Anthony_Scott_Miller',
#  'Mohammad_Khatami',
#  'John_Reilly',
#  'Carlos_Ruckauf',
#  'Randy_Travis',
#  'Edward_Kennedy',
#  'Elisabeth_Schumacher',
#  'Sheikh_Ahmed_Yassin',
#  'John_Fox',
#  'Noelle_Bush',
#  'Bryan_Cooley',
#  'Jean-Luc_Bideau',
#  'Rick_Barnes',
#  'Sushma_Swaraj',
#  'Bill_Simon',
#  'Robert_Lee_Yates_Jr',
#  'Frank_Lautenberg',
#  'Farouk_Kaddoumi',
#  'Ricardo_Lopez_Murphy',
#  'Bridget_Fonda',
#  'Vijay_Nambiar',
#  'BB_King',
#  'Dan_Bylsma',
#  'Art_Cooper',
#  'Carey_Lowell',
#  'Seth_Gorney',
#  'Danny_Avalon',
#  'Patrick_Roy',
#  'Christian_Lirette',
#  'Garry_Witherall',
#  'Elinor_Caplan',
#  'Rose_Marie',
#  'Bobby_Bowden',
#  'Chris_Cornell',
#  'Eriko_Tamura',
#  'Benazir_Bhutto',
#  'Dan_Bartlett',
#  'Brooke_Gordon',
#  'Paula_Zahn',
#  'Bryant_Young',
#  'Patty_Sheehan',
#  'Condoleezza_Rice',
#  'Silvan_Shalom',
#  'Halbert_Fillinger',
#  'Mike_Martz',
#  'Habib_Hisham',
#  'Dave_Ragone',
#  'Iveta_Benesova',
#  'Joshua_Harapko',
#  'Chris_Noth',
#  'Bronson_Arroyo',
#  'Frank_Abagnale_Jr',
#  'Amber_Frey',
#  'James_Baker',
#  'Mary_Tyler_Moore',
#  'Darryl_McDaniels',
#  'Ashton_Kutcher',
#  'Lisa_Leslie',
#  'Urmila_Matondkar',
#  'Himmler_Rebu',
#  'Rina_Lazo',
#  'Daniel_Scioli',
#  'Lucie_Lapovsky',
#  'Taufik_Kiemas',
#  'Pascal_Quignard',
#  'Troy_Jenkins',
#  'Gil_Cates',
#  'Catriona_Le_May_Doan',
#  'Phillip_Fulmer',
#  'Norodom_Sihanouk',
#  'Jayne_Yarris',
#  'Steve_Backley',
#  'Alexis_Dennisoff',
#  'Francis_Collins',
#  'Mickey_Sherman',
#  'Ziwang_Xu',
#  'Cathy_Cunningham',
#  'Ahmet_Demir',
#  'Marcus_Garrettson',
#  'Massoud_Barzani',
#  'Denzel_Washington',
#  'Sun_Myung_Moon',
#  'James_Carville',
#  'Billy_Crawford',
#  'Jen_Schefft',
#  'Huang_Suey-Sheng',
#  'Kara_Lynn_Joyce',
#  'Richard_Regenhard',
#  'Joe_Cravens',
#  'Dave_Tucker',
#  'Peter_Chan',
#  'Lucas_Wysocki',
#  'Szu_Yu_Chen',
#  'Charles_Bell',
#  'James_Jones',
#  'Alison_Krauss',
#  'Osmond_Smith',
#  'Bode_Miller',
#  'Giuseppe_Morchio',
#  'Anjum_Hussain',
#  'Joseph_LePore',
#  'Francisco_Garcia',
#  'John_Warner',
#  'Jim_Piper',
#  'Tamika_Catchings',
#  'Mario_Dumont',
#  'Kwon_Young-gil',
#  'Andre_Techine',
#  'Doug_Melvin',
#  'Christine_Baumgartner',
#  'Paul_Kariya',
#  'Michael_Olowokandi',
#  'Adrien_Brody',
#  'Robbie_Williams',
#  'Debra_Rose',
#  'Stephen_Joseph',
#  'Gary_Doer',
#  'Marwan_Barghouthi',
#  'Kenny_Chesney',
#  'Ali_Hammoud',
#  'Suh_Chung-won',
#  'Julien_Varlet',
#  'Jamie_Carey',
#  'Karen_Clarkson',
#  'Hannah_Stockbauer',
#  'Tali_Imani',
#  'Elvis_Stojko',
#  'Matt_LeBlanc',
#  ...]

# %%
for directory in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw', directory)):
        EX_PATH = os.path.join('lfw', directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)
        os.replace(EX_PATH, NEW_PATH)
